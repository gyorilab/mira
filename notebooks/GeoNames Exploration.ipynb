# %% [markdown]
# # GeoNames Exploration
#
#
# All files listed on https://download.geonames.org/export/dump/readme.txt. Pre-computed city lists:
#
# | File | Description |
# |------|------|
# | cities500.zip            | all cities with a population > 500 or seats of adm div down to PPLA4 (ca 185.000), see 'geoname' table for columns |
# | cities1000.zip           | all cities with a population > 1000 or seats of adm div down to PPLA3 (ca 130.000), see 'geoname' table for columns |
# | cities5000.zip           | all cities with a population > 5000 or PPLA (ca 50.000), see 'geoname' table for columns |
# | cities15000.zip          | all cities with a population > 15000 or capitals (ca 25.000), see 'geoname' table for columns |

# %% [markdown]
# The main 'geoname' table has the following fields :
# ---------------------------------------------------
# | Label | Description | Type |
# |------------|------------|------|
# | geonameid         | integer id of record in geonames database | integer |
# | name              | name of geographical point (utf8) | varchar(200) |
# | asciiname         | name of geographical point in plain ascii characters | varchar(200)
# | alternatenames    | alternatenames, comma separated, ascii names automatically transliterated, convenience attribute from alternatename table |  varchar(10000)
# | latitude          | latitude in decimal degrees | (wgs84)
# | longitude         | longitude in decimal degrees | (wgs84)
# | feature class     | see http://www.geonames.org/export/codes.html | char(1)
# | feature code      | see http://www.geonames.org/export/codes.html | varchar(10)
# | country code      | ISO-3166 2-letter country code | 2 characters
# | cc2               | alternate country codes, comma separated ISO-3166 2-letter country code | 200 characters
# | admin1 code       | fipscode (subject to change to iso code), see exceptions below, see file admin1Codes.txt for display names of this code | varchar(20)
# | admin2 code       | code for the second administrative division, a county in the US, see file admin2Codes.txt; | varchar(80)
# | admin3 code       | code for third level administrative division | varchar(20)
# | admin4 code       | code for fourth level administrative division | varchar(20)
# | population        | bigint | (8 byte int)
# | elevation         | in meters |  integer
# | dem               | digital elevation model, srtm3 or gtopo30, average elevation of 3''x3'' (ca 90mx90m) or 30''x30'' (ca 900mx900m) area in meters, integer. srtm processed by cgiar/ciat.
# | timezone          | the iana timezone id (see file timeZone.txt) |  varchar(40)
# | modification date | date of last modification in |  yyyy-MM-dd format

# %%
import pystow
from pyobo import Obo, Term, Reference
from pyobo.struct import part_of
import pandas as pd
MODULE = pystow.module("mira", "geonames")

# %%
terms = {}

# %%
COUNTRIES_URL = "https://download.geonames.org/export/dump/countryInfo.txt"

countries_df = MODULE.ensure_csv(
    url=COUNTRIES_URL,
    read_csv_kwargs=dict(
        skiprows=49,
        keep_default_na=False, # NA is a country code
    ),
)
reorder = ["geonameid", *(c for c in countries_df.columns if c != "geonameid")]
countries_df = countries_df[reorder]
countries_df
# Out:
#      geonameid #ISO ISO3  ISO-Numeric fips                Country  \
# 0      3041565   AD  AND           20   AN                Andorra
# 1       290557   AE  ARE          784   AE   United Arab Emirates
# 2      1149361   AF  AFG            4   AF            Afghanistan
# 3      3576396   AG  ATG           28   AC    Antigua and Barbuda
# 4      3573511   AI  AIA          660   AV               Anguilla
# ..         ...  ...  ...          ...  ...                    ...
# 247     953987   ZA  ZAF          710   SF           South Africa
# 248     895949   ZM  ZMB          894   ZA                 Zambia
# 249     878675   ZW  ZWE          716   ZI               Zimbabwe
# 250    8505033   CS  SCG          891   YI  Serbia and Montenegro
# 251    8505032   AN  ANT          530   NT   Netherlands Antilles
#
#               Capital  Area(in sq km)  Population Continent  tld CurrencyCode  \
# 0    Andorra la Vella           468.0       77006        EU  .ad          EUR
# 1           Abu Dhabi         82880.0     9630959        AS  .ae          AED
# 2               Kabul        647500.0    37172386        AS  .af          AFN
# 3          St. John's           443.0       96286        NA  .ag          XCD
# 4          The Valley           102.0       13254        NA  .ai          XCD
# ..                ...             ...         ...       ...  ...          ...
# 247          Pretoria       1219912.0    57779622        AF  .za          ZAR
# 248            Lusaka        752614.0    17351822        AF  .zm          ZMW
# 249            Harare        390580.0    14439018        AF  .zw          ZWL
# 250          Belgrade        102350.0    10829175        EU  .cs          RSD
# 251        Willemstad           960.0      300000        NA  .an          ANG
#
#     CurrencyName   Phone Postal Code Format Postal Code Regex  \
# 0           Euro     376              AD###  ^(?:AD)*(\d{3})$
# 1         Dirham     971
# 2        Afghani      93
# 3         Dollar  +1-268
# 4         Dollar  +1-264
# ..           ...     ...                ...               ...
# 247         Rand      27               ####         ^(\d{4})$
# 248       Kwacha     260              #####         ^(\d{5})$
# 249       Dollar     263
# 250        Dinar     381              #####         ^(\d{5})$
# 251      Guilder     599
#
#                                 Languages            neighbours  \
# 0                                      ca                 ES,FR
# 1                       ar-AE,fa,en,hi,ur                 SA,OM
# 2                       fa-AF,ps,uz-AF,tk     TM,CN,IR,TJ,PK,UZ
# 3                                   en-AG
# 4                                   en-AI
# ..                                    ...                   ...
# 247  zu,xh,af,nso,en-ZA,tn,st,ts,ss,ve,nr     ZW,SZ,MZ,BW,NA,LS
# 248          en-ZM,bem,loz,lun,lue,ny,toi  ZW,TZ,MZ,CD,NA,MW,AO
# 249                        en-ZW,sn,nr,nd           ZA,MZ,BW,ZM
# 250                           cu,hu,sq,sr  AL,HU,MK,RO,HR,BA,BG
# 251                           nl-AN,en,es                    GP
#
#     EquivalentFipsCode
# 0
# 1
# 2
# 3
# 4
# ..                 ...
# 247
# 248
# 249
# 250
# 251
#
# [252 rows x 19 columns]

# %%
code_to_country = {}
cols = ["geonameid", "Country", "#ISO"]
for identifier, name, code in countries_df[cols].values:
    terms[identifier] = term = Term.from_triple("geonames", identifier, name)
    term.append_property("code", code)
    code_to_country[code] = term

# %%
ADMIN1_URL = "https://download.geonames.org/export/dump/admin1CodesASCII.txt"

admin1_df = MODULE.ensure_csv(
    url=ADMIN1_URL,
    read_csv_kwargs=dict(
        header=None,
        names=["code", "name", "asciiname", "geonames_id"],
    ),
)
admin1_df = admin1_df[["geonames_id", "code", "name", "asciiname"]]
admin1_df.head()
# Out:
#    geonames_id   code                 name            asciiname
# 0      3039162  AD.06  Sant Julià de Loria  Sant Julia de Loria
# 1      3039676  AD.05               Ordino               Ordino
# 2      3040131  AD.04           La Massana           La Massana
# 3      3040684  AD.03               Encamp               Encamp
# 4      3041203  AD.02              Canillo              Canillo

# %%
code_to_admin1 = {}
cols = ["geonames_id", "name", "code"]
for identifier, name, code in admin1_df[cols].values:
    term = Term.from_triple("geonames", identifier, name)
    term.append_property("code", code)
    terms[identifier] = term
    code_to_admin1[code] = term
    
    country_code = code.split('.')[0]
    country_term = code_to_country[country_code]
    term.append_relationship(part_of, country_term)

# %%
ADMIN2_URL = "https://download.geonames.org/export/dump/admin2Codes.txt"
admin2_df = MODULE.ensure_csv(
    url=ADMIN2_URL,
    read_csv_kwargs=dict(
        header=None,
        names=["code", "name", "asciiname", "geonames_id"],
    ),
)
admin2_df = admin2_df[["geonames_id", "code", "name", "asciiname"]]
admin2_df.head()
# Out:
#    geonames_id       code                            name  \
# 0     12047239  AE.01.101          Abu Dhabi Municipality
# 1     12047240  AE.01.102             Al Ain Municipality
# 2     12047241  AE.01.103                       Al Dhafra
# 3     12047242  AE.04.701        Al Fujairah Municipality
# 4     12047243  AE.04.702  Dibba Al Fujairah Municipality
#
#                         asciiname
# 0          Abu Dhabi Municipality
# 1             Al Ain Municipality
# 2                       Al Dhafra
# 3        Al Fujairah Municipality
# 4  Dibba Al Fujairah Municipality

# %%
code_to_admin2 = {}
for identifier, name, code in admin2_df[["geonames_id", "name", "code"]].values:
    term = Term.from_triple("geonames", identifier, name)
    term.append_property("code", code)
    terms[identifier] = term
    code_to_admin2[code] = term
    
    admin1_code = code.rsplit('.', 1)[0]
    admin1_term = code_to_admin1[admin1_code]
    term.append_relationship(part_of, admin1_term)

# %%
terms
# Out:
# {3041565: Term(reference=Reference(prefix='geonames', identifier=3041565, name='Andorra'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['AD']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  290557: Term(reference=Reference(prefix='geonames', identifier=290557, name='United Arab Emirates'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['AE']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1149361: Term(reference=Reference(prefix='geonames', identifier=1149361, name='Afghanistan'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['AF']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3576396: Term(reference=Reference(prefix='geonames', identifier=3576396, name='Antigua and Barbuda'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['AG']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3573511: Term(reference=Reference(prefix='geonames', identifier=3573511, name='Anguilla'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['AI']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  783754: Term(reference=Reference(prefix='geonames', identifier=783754, name='Albania'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['AL']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  174982: Term(reference=Reference(prefix='geonames', identifier=174982, name='Armenia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['AM']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3351879: Term(reference=Reference(prefix='geonames', identifier=3351879, name='Angola'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['AO']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  6697173: Term(reference=Reference(prefix='geonames', identifier=6697173, name='Antarctica'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['AQ']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3865483: Term(reference=Reference(prefix='geonames', identifier=3865483, name='Argentina'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['AR']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  5880801: Term(reference=Reference(prefix='geonames', identifier=5880801, name='American Samoa'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['AS']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2782113: Term(reference=Reference(prefix='geonames', identifier=2782113, name='Austria'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['AT']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2077456: Term(reference=Reference(prefix='geonames', identifier=2077456, name='Australia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['AU']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3577279: Term(reference=Reference(prefix='geonames', identifier=3577279, name='Aruba'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['AW']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  661882: Term(reference=Reference(prefix='geonames', identifier=661882, name='Aland Islands'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['AX']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  587116: Term(reference=Reference(prefix='geonames', identifier=587116, name='Azerbaijan'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['AZ']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3277605: Term(reference=Reference(prefix='geonames', identifier=3277605, name='Bosnia and Herzegovina'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BA']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3374084: Term(reference=Reference(prefix='geonames', identifier=3374084, name='Barbados'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BB']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1210997: Term(reference=Reference(prefix='geonames', identifier=1210997, name='Bangladesh'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BD']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2802361: Term(reference=Reference(prefix='geonames', identifier=2802361, name='Belgium'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BE']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2361809: Term(reference=Reference(prefix='geonames', identifier=2361809, name='Burkina Faso'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BF']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  732800: Term(reference=Reference(prefix='geonames', identifier=732800, name='Bulgaria'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BG']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  290291: Term(reference=Reference(prefix='geonames', identifier=290291, name='Bahrain'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BH']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  433561: Term(reference=Reference(prefix='geonames', identifier=433561, name='Burundi'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BI']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2395170: Term(reference=Reference(prefix='geonames', identifier=2395170, name='Benin'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BJ']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3578476: Term(reference=Reference(prefix='geonames', identifier=3578476, name='Saint Barthelemy'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BL']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3573345: Term(reference=Reference(prefix='geonames', identifier=3573345, name='Bermuda'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BM']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1820814: Term(reference=Reference(prefix='geonames', identifier=1820814, name='Brunei'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BN']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3923057: Term(reference=Reference(prefix='geonames', identifier=3923057, name='Bolivia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BO']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  7626844: Term(reference=Reference(prefix='geonames', identifier=7626844, name='Bonaire, Saint Eustatius and Saba '), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BQ']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3469034: Term(reference=Reference(prefix='geonames', identifier=3469034, name='Brazil'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BR']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3572887: Term(reference=Reference(prefix='geonames', identifier=3572887, name='Bahamas'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BS']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1252634: Term(reference=Reference(prefix='geonames', identifier=1252634, name='Bhutan'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BT']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3371123: Term(reference=Reference(prefix='geonames', identifier=3371123, name='Bouvet Island'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BV']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  933860: Term(reference=Reference(prefix='geonames', identifier=933860, name='Botswana'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BW']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  630336: Term(reference=Reference(prefix='geonames', identifier=630336, name='Belarus'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BY']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3582678: Term(reference=Reference(prefix='geonames', identifier=3582678, name='Belize'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['BZ']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  6251999: Term(reference=Reference(prefix='geonames', identifier=6251999, name='Canada'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CA']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1547376: Term(reference=Reference(prefix='geonames', identifier=1547376, name='Cocos Islands'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CC']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  203312: Term(reference=Reference(prefix='geonames', identifier=203312, name='Democratic Republic of the Congo'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CD']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  239880: Term(reference=Reference(prefix='geonames', identifier=239880, name='Central African Republic'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CF']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2260494: Term(reference=Reference(prefix='geonames', identifier=2260494, name='Republic of the Congo'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CG']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2658434: Term(reference=Reference(prefix='geonames', identifier=2658434, name='Switzerland'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CH']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2287781: Term(reference=Reference(prefix='geonames', identifier=2287781, name='Ivory Coast'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CI']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1899402: Term(reference=Reference(prefix='geonames', identifier=1899402, name='Cook Islands'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CK']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3895114: Term(reference=Reference(prefix='geonames', identifier=3895114, name='Chile'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CL']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2233387: Term(reference=Reference(prefix='geonames', identifier=2233387, name='Cameroon'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CM']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1814991: Term(reference=Reference(prefix='geonames', identifier=1814991, name='China'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CN']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3686110: Term(reference=Reference(prefix='geonames', identifier=3686110, name='Colombia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CO']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3624060: Term(reference=Reference(prefix='geonames', identifier=3624060, name='Costa Rica'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CR']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3562981: Term(reference=Reference(prefix='geonames', identifier=3562981, name='Cuba'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CU']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3374766: Term(reference=Reference(prefix='geonames', identifier=3374766, name='Cabo Verde'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  7626836: Term(reference=Reference(prefix='geonames', identifier=7626836, name='Curacao'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CW']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2078138: Term(reference=Reference(prefix='geonames', identifier=2078138, name='Christmas Island'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CX']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  146669: Term(reference=Reference(prefix='geonames', identifier=146669, name='Cyprus'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CY']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3077311: Term(reference=Reference(prefix='geonames', identifier=3077311, name='Czechia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CZ']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2921044: Term(reference=Reference(prefix='geonames', identifier=2921044, name='Germany'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['DE']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  223816: Term(reference=Reference(prefix='geonames', identifier=223816, name='Djibouti'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['DJ']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2623032: Term(reference=Reference(prefix='geonames', identifier=2623032, name='Denmark'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['DK']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3575830: Term(reference=Reference(prefix='geonames', identifier=3575830, name='Dominica'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['DM']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3508796: Term(reference=Reference(prefix='geonames', identifier=3508796, name='Dominican Republic'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['DO']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2589581: Term(reference=Reference(prefix='geonames', identifier=2589581, name='Algeria'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['DZ']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3658394: Term(reference=Reference(prefix='geonames', identifier=3658394, name='Ecuador'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['EC']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  453733: Term(reference=Reference(prefix='geonames', identifier=453733, name='Estonia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['EE']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  357994: Term(reference=Reference(prefix='geonames', identifier=357994, name='Egypt'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['EG']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2461445: Term(reference=Reference(prefix='geonames', identifier=2461445, name='Western Sahara'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['EH']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  338010: Term(reference=Reference(prefix='geonames', identifier=338010, name='Eritrea'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['ER']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2510769: Term(reference=Reference(prefix='geonames', identifier=2510769, name='Spain'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['ES']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  337996: Term(reference=Reference(prefix='geonames', identifier=337996, name='Ethiopia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['ET']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  660013: Term(reference=Reference(prefix='geonames', identifier=660013, name='Finland'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['FI']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2205218: Term(reference=Reference(prefix='geonames', identifier=2205218, name='Fiji'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['FJ']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3474414: Term(reference=Reference(prefix='geonames', identifier=3474414, name='Falkland Islands'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['FK']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2081918: Term(reference=Reference(prefix='geonames', identifier=2081918, name='Micronesia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['FM']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2622320: Term(reference=Reference(prefix='geonames', identifier=2622320, name='Faroe Islands'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['FO']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3017382: Term(reference=Reference(prefix='geonames', identifier=3017382, name='France'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['FR']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2400553: Term(reference=Reference(prefix='geonames', identifier=2400553, name='Gabon'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GA']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2635167: Term(reference=Reference(prefix='geonames', identifier=2635167, name='United Kingdom'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GB']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3580239: Term(reference=Reference(prefix='geonames', identifier=3580239, name='Grenada'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GD']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  614540: Term(reference=Reference(prefix='geonames', identifier=614540, name='Georgia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GE']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3381670: Term(reference=Reference(prefix='geonames', identifier=3381670, name='French Guiana'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GF']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3042362: Term(reference=Reference(prefix='geonames', identifier=3042362, name='Guernsey'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GG']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2300660: Term(reference=Reference(prefix='geonames', identifier=2300660, name='Ghana'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GH']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2411586: Term(reference=Reference(prefix='geonames', identifier=2411586, name='Gibraltar'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GI']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3425505: Term(reference=Reference(prefix='geonames', identifier=3425505, name='Greenland'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GL']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2413451: Term(reference=Reference(prefix='geonames', identifier=2413451, name='Gambia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GM']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2420477: Term(reference=Reference(prefix='geonames', identifier=2420477, name='Guinea'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GN']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3579143: Term(reference=Reference(prefix='geonames', identifier=3579143, name='Guadeloupe'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GP']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2309096: Term(reference=Reference(prefix='geonames', identifier=2309096, name='Equatorial Guinea'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GQ']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  390903: Term(reference=Reference(prefix='geonames', identifier=390903, name='Greece'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GR']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3474415: Term(reference=Reference(prefix='geonames', identifier=3474415, name='South Georgia and the South Sandwich Islands'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GS']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3595528: Term(reference=Reference(prefix='geonames', identifier=3595528, name='Guatemala'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GT']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  4043988: Term(reference=Reference(prefix='geonames', identifier=4043988, name='Guam'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GU']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2372248: Term(reference=Reference(prefix='geonames', identifier=2372248, name='Guinea-Bissau'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GW']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3378535: Term(reference=Reference(prefix='geonames', identifier=3378535, name='Guyana'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['GY']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1819730: Term(reference=Reference(prefix='geonames', identifier=1819730, name='Hong Kong'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['HK']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1547314: Term(reference=Reference(prefix='geonames', identifier=1547314, name='Heard Island and McDonald Islands'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['HM']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3608932: Term(reference=Reference(prefix='geonames', identifier=3608932, name='Honduras'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['HN']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3202326: Term(reference=Reference(prefix='geonames', identifier=3202326, name='Croatia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['HR']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3723988: Term(reference=Reference(prefix='geonames', identifier=3723988, name='Haiti'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['HT']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  719819: Term(reference=Reference(prefix='geonames', identifier=719819, name='Hungary'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['HU']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1643084: Term(reference=Reference(prefix='geonames', identifier=1643084, name='Indonesia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['ID']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2963597: Term(reference=Reference(prefix='geonames', identifier=2963597, name='Ireland'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['IE']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  294640: Term(reference=Reference(prefix='geonames', identifier=294640, name='Israel'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['IL']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3042225: Term(reference=Reference(prefix='geonames', identifier=3042225, name='Isle of Man'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['IM']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1269750: Term(reference=Reference(prefix='geonames', identifier=1269750, name='India'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['IN']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1282588: Term(reference=Reference(prefix='geonames', identifier=1282588, name='British Indian Ocean Territory'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['IO']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  99237: Term(reference=Reference(prefix='geonames', identifier=99237, name='Iraq'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['IQ']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  130758: Term(reference=Reference(prefix='geonames', identifier=130758, name='Iran'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['IR']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2629691: Term(reference=Reference(prefix='geonames', identifier=2629691, name='Iceland'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['IS']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3175395: Term(reference=Reference(prefix='geonames', identifier=3175395, name='Italy'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['IT']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3042142: Term(reference=Reference(prefix='geonames', identifier=3042142, name='Jersey'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['JE']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3489940: Term(reference=Reference(prefix='geonames', identifier=3489940, name='Jamaica'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['JM']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  248816: Term(reference=Reference(prefix='geonames', identifier=248816, name='Jordan'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['JO']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1861060: Term(reference=Reference(prefix='geonames', identifier=1861060, name='Japan'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['JP']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  192950: Term(reference=Reference(prefix='geonames', identifier=192950, name='Kenya'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['KE']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1527747: Term(reference=Reference(prefix='geonames', identifier=1527747, name='Kyrgyzstan'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['KG']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1831722: Term(reference=Reference(prefix='geonames', identifier=1831722, name='Cambodia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['KH']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  4030945: Term(reference=Reference(prefix='geonames', identifier=4030945, name='Kiribati'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['KI']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  921929: Term(reference=Reference(prefix='geonames', identifier=921929, name='Comoros'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['KM']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3575174: Term(reference=Reference(prefix='geonames', identifier=3575174, name='Saint Kitts and Nevis'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['KN']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1873107: Term(reference=Reference(prefix='geonames', identifier=1873107, name='North Korea'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['KP']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1835841: Term(reference=Reference(prefix='geonames', identifier=1835841, name='South Korea'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['KR']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  831053: Term(reference=Reference(prefix='geonames', identifier=831053, name='Kosovo'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['XK']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  285570: Term(reference=Reference(prefix='geonames', identifier=285570, name='Kuwait'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['KW']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3580718: Term(reference=Reference(prefix='geonames', identifier=3580718, name='Cayman Islands'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['KY']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1522867: Term(reference=Reference(prefix='geonames', identifier=1522867, name='Kazakhstan'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['KZ']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1655842: Term(reference=Reference(prefix='geonames', identifier=1655842, name='Laos'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['LA']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  272103: Term(reference=Reference(prefix='geonames', identifier=272103, name='Lebanon'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['LB']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3576468: Term(reference=Reference(prefix='geonames', identifier=3576468, name='Saint Lucia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['LC']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3042058: Term(reference=Reference(prefix='geonames', identifier=3042058, name='Liechtenstein'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['LI']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1227603: Term(reference=Reference(prefix='geonames', identifier=1227603, name='Sri Lanka'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['LK']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2275384: Term(reference=Reference(prefix='geonames', identifier=2275384, name='Liberia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['LR']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  932692: Term(reference=Reference(prefix='geonames', identifier=932692, name='Lesotho'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['LS']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  597427: Term(reference=Reference(prefix='geonames', identifier=597427, name='Lithuania'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['LT']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2960313: Term(reference=Reference(prefix='geonames', identifier=2960313, name='Luxembourg'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['LU']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  458258: Term(reference=Reference(prefix='geonames', identifier=458258, name='Latvia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['LV']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2215636: Term(reference=Reference(prefix='geonames', identifier=2215636, name='Libya'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['LY']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2542007: Term(reference=Reference(prefix='geonames', identifier=2542007, name='Morocco'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['MA']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2993457: Term(reference=Reference(prefix='geonames', identifier=2993457, name='Monaco'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['MC']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  617790: Term(reference=Reference(prefix='geonames', identifier=617790, name='Moldova'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['MD']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3194884: Term(reference=Reference(prefix='geonames', identifier=3194884, name='Montenegro'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['ME']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3578421: Term(reference=Reference(prefix='geonames', identifier=3578421, name='Saint Martin'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['MF']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  1062947: Term(reference=Reference(prefix='geonames', identifier=1062947, name='Madagascar'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['MG']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2080185: Term(reference=Reference(prefix='geonames', identifier=2080185, name='Marshall Islands'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['MH']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  718075: Term(reference=Reference(prefix='geonames', identifier=718075, name='North Macedonia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['MK']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2453866: Term(reference=Reference(prefix='geonames', identifier=2453866, name='Mali'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['ML']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
# ...
#  3374226: Term(reference=Reference(prefix='geonames', identifier=3374226, name='Santa Catarina'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.15']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3374249: Term(reference=Reference(prefix='geonames', identifier=3374249, name='Sal'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.08']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3374274: Term(reference=Reference(prefix='geonames', identifier=3374274, name='Ribeira Grande'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.07']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3374332: Term(reference=Reference(prefix='geonames', identifier=3374332, name='Praia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.14']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3374391: Term(reference=Reference(prefix='geonames', identifier=3374391, name='Paul'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.05']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3374487: Term(reference=Reference(prefix='geonames', identifier=3374487, name='Maio'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.04']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3374832: Term(reference=Reference(prefix='geonames', identifier=3374832, name='Brava'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.02']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3374855: Term(reference=Reference(prefix='geonames', identifier=3374855, name='Boa Vista'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.01']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3411924: Term(reference=Reference(prefix='geonames', identifier=3411924, name='Mosteiros'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.13']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3411925: Term(reference=Reference(prefix='geonames', identifier=3411925, name='Santa Cruz'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.16']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3411926: Term(reference=Reference(prefix='geonames', identifier=3411926, name='São Domingos'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.17']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3411927: Term(reference=Reference(prefix='geonames', identifier=3411927, name='São Filipe'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.18']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3411928: Term(reference=Reference(prefix='geonames', identifier=3411928, name='São Miguel'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.19']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  7602868: Term(reference=Reference(prefix='geonames', identifier=7602868, name='Porto Novo'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.21']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  7602869: Term(reference=Reference(prefix='geonames', identifier=7602869, name='Ribeira Brava'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.22']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  7602870: Term(reference=Reference(prefix='geonames', identifier=7602870, name='Santa Catarina do Fogo'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.24']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  7602871: Term(reference=Reference(prefix='geonames', identifier=7602871, name='São Salvador do Mundo'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.26']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  7602872: Term(reference=Reference(prefix='geonames', identifier=7602872, name='Tarrafal de São Nicolau'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.27']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  7602873: Term(reference=Reference(prefix='geonames', identifier=7602873, name='São Lourenço dos Órgãos'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.25']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  7603281: Term(reference=Reference(prefix='geonames', identifier=7603281, name='Ribeira Grande de Santiago'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CV.23']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  146213: Term(reference=Reference(prefix='geonames', identifier=146213, name='Pafos'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CY.06']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  146267: Term(reference=Reference(prefix='geonames', identifier=146267, name='Nicosia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CY.04']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  146383: Term(reference=Reference(prefix='geonames', identifier=146383, name='Limassol'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CY.05']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  146398: Term(reference=Reference(prefix='geonames', identifier=146398, name='Larnaka'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CY.03']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  146411: Term(reference=Reference(prefix='geonames', identifier=146411, name='Keryneia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CY.02']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  146615: Term(reference=Reference(prefix='geonames', identifier=146615, name='Ammochostos'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CY.01']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3067695: Term(reference=Reference(prefix='geonames', identifier=3067695, name='Hlavní město Praha'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CZ.52']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3339536: Term(reference=Reference(prefix='geonames', identifier=3339536, name='South Moravian'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CZ.78']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3339537: Term(reference=Reference(prefix='geonames', identifier=3339537, name='Jihočeský kraj'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CZ.79']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3339538: Term(reference=Reference(prefix='geonames', identifier=3339538, name='Vysočina'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CZ.80']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3339539: Term(reference=Reference(prefix='geonames', identifier=3339539, name='Karlovarský kraj'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CZ.81']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3339540: Term(reference=Reference(prefix='geonames', identifier=3339540, name='Královéhradecký kraj'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CZ.82']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3339541: Term(reference=Reference(prefix='geonames', identifier=3339541, name='Liberecký kraj'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CZ.83']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3339542: Term(reference=Reference(prefix='geonames', identifier=3339542, name='Olomoucký'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CZ.84']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3339573: Term(reference=Reference(prefix='geonames', identifier=3339573, name='Moravskoslezský'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CZ.85']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3339574: Term(reference=Reference(prefix='geonames', identifier=3339574, name='Pardubický'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CZ.86']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3339575: Term(reference=Reference(prefix='geonames', identifier=3339575, name='Plzeň Region'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CZ.87']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3339576: Term(reference=Reference(prefix='geonames', identifier=3339576, name='Central Bohemia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CZ.88']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3339577: Term(reference=Reference(prefix='geonames', identifier=3339577, name='Ústecký kraj'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CZ.89']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  3339578: Term(reference=Reference(prefix='geonames', identifier=3339578, name='Zlín'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['CZ.90']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2822542: Term(reference=Reference(prefix='geonames', identifier=2822542, name='Thuringia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['DE.15']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2838632: Term(reference=Reference(prefix='geonames', identifier=2838632, name='Schleswig-Holstein'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['DE.10']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2842565: Term(reference=Reference(prefix='geonames', identifier=2842565, name='Saxony-Anhalt'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['DE.14']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2842566: Term(reference=Reference(prefix='geonames', identifier=2842566, name='Saxony'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['DE.13']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2842635: Term(reference=Reference(prefix='geonames', identifier=2842635, name='Saarland'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['DE.09']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2847618: Term(reference=Reference(prefix='geonames', identifier=2847618, name='Rheinland-Pfalz'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['DE.08']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2861876: Term(reference=Reference(prefix='geonames', identifier=2861876, name='North Rhine-Westphalia'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['DE.07']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  2862926: Term(reference=Reference(prefix='geonames', identifier=2862926, name='Lower Saxony'), definition=None, provenance=[], relationships=defaultdict(<class 'list'>, {}), properties=defaultdict(<class 'list'>, {'code': ['DE.06']}), parents=[], synonyms=[], xrefs=[], xref_types=[], alt_ids=[], namespace=None, is_obsolete=None),
#  ...}

# %%
CITIES_URL = "https://download.geonames.org/export/dump/cities15000.zip"
columns = [
    "geonames_id", "name", "asciiname", "synonyms", 
    "latitude", "longitude", "feature_class", "feature_code", "country_code", "cc2",  
    "admin1", "admin2", "admin3", "admin4",
    "population", "elevation", "dem", "timezone", "date_modified"
]
cities_df = pystow.ensure_zip_df(
    "mira", "geonames", 
    url=CITIES_URL, inner_path="cities15000.txt",
    read_csv_kwargs=dict(
        header=None,
        names=columns
    ),
)
cities_df =  cities_df[cities_df.population > 60_000]
cities_df.synonyms = cities_df.synonyms.str.split(",")
cities_df
# Out:
#        geonames_id                 name            asciiname  \
# 2           290594   Umm Al Quwain City   Umm Al Quwain City
# 3           291074  Ras Al Khaimah City  Ras Al Khaimah City
# 4           291580           Zayed City           Zayed City
# 6           292223                Dubai                Dubai
# 9           292672              Sharjah              Sharjah
# ...            ...                  ...                  ...
# 26437       893697             Chinhoyi             Chinhoyi
# 26438       894239              Chegutu              Chegutu
# 26439       894701             Bulawayo             Bulawayo
# 26442      1085510              Epworth              Epworth
# 26443      1106542          Chitungwiza          Chitungwiza
#
#                                                 synonyms  latitude  longitude  \
# 2      [Oumm al Qaiwain, Oumm al Qaïwaïn, Um al Kawai...  25.56473   55.55517
# 3      [Julfa, Khaimah, RAK City, RKT, Ra's al Khayma...  25.78953   55.94320
# 4      [Bid' Zayed, Bid’ Zayed, Madinat Za'id, Madina...  23.65416   53.70522
# 6      [DXB, Dabei, Dibai, Dibay, Doubayi, Dubae, Dub...  25.07725   55.30927
# 9      [Al Sharjah, Ash 'Mariqah, Ash Shariqa, Ash Sh...  25.33737   55.41206
# ...                                                  ...       ...        ...
# 26437  [Chinhoyi, Chinkhoi, Chinkhoji, Chinoyi, Cinho... -17.36667   30.20000
# 26438           [Cheguto, Chegutu, Hartley, New Hartley] -18.13021   30.14074
# 26439  [BUQ, Bulavajas, Bulavajo, Bulavejo, Bulawayo,... -20.15000   28.58333
# 26442                                          [Epworth] -17.89000   31.14750
# 26443  [Chitungviza, Chitungwiza, Chytungviza, Citung... -18.01274   31.07555
#
#       feature_class feature_code country_code  cc2 admin1 admin2 admin3  \
# 2                 P         PPLA           AE  NaN     07    NaN    NaN
# 3                 P         PPLA           AE  NaN     05    NaN    NaN
# 4                 P          PPL           AE  NaN     01    103    NaN
# 6                 P         PPLA           AE  NaN     03    NaN    NaN
# 9                 P         PPLA           AE  NaN     06    NaN    NaN
# ...             ...          ...          ...  ...    ...    ...    ...
# 26437             P         PPLA           ZW  NaN     05    NaN    NaN
# 26438             P          PPL           ZW  NaN     05    NaN    NaN
# 26439             P         PPLA           ZW  NaN     09    NaN    NaN
# 26442             P         PPLX           ZW  NaN     10    NaN    NaN
# 26443             P          PPL           ZW  NaN     10    NaN    NaN
#
#       admin4  population  elevation   dem       timezone date_modified
# 2        NaN       62747        NaN     2     Asia/Dubai    2019-10-24
# 3        NaN      351943        NaN     2     Asia/Dubai    2019-09-09
# 4        NaN       63482        NaN   118     Asia/Dubai    2019-10-24
# 6        NaN     3478300        NaN    24     Asia/Dubai    2022-06-14
# 9        NaN     1274749        NaN     6     Asia/Dubai    2023-02-27
# ...      ...         ...        ...   ...            ...           ...
# 26437    NaN       90800        NaN  1153  Africa/Harare    2023-02-24
# 26438    NaN       65800        NaN  1187  Africa/Harare    2022-10-07
# 26439    NaN     1200337        NaN  1348  Africa/Harare    2023-02-24
# 26442    NaN      123250        NaN  1508  Africa/Harare    2012-01-19
# 26443    NaN      371244        NaN  1435  Africa/Harare    2022-10-05
#
# [8288 rows x 19 columns]

# %%
cols = ["geonames_id", "name", "synonyms", "country_code", "admin1", "admin2"]
for identifier, name, synonyms, country, admin1, admin2 in cities_df[cols].values:
    term = Term.from_triple("geonames", identifier, name)
    if synonyms and not isinstance(synonyms, float):
        for synoynm in synonyms:
            term.append_synonym(synoynm)
    if pd.notna(admin2):
        admin2_full = f"{country}.{admin1}.{admin2}"
        admin2_term = code_to_admin2.get(admin2_full)
        if admin2_term is not None:
            term.append_relationship(part_of, admin2_term)
        else:
            pass
            print("could not find admin2", admin2_full)
    elif pd.notna(admin1):
        admin1_full = f"{country}.{admin1}"
        admin1_term = code_to_admin1.get(admin1_full)
        if admin1_term is not None:
            term.append_relationship(part_of, admin1_term)
        else:
            print("could not find admin1", admin1_full)
    else:
        print("missing admin codes", identifier, name, country)
# Out:
# could not find admin2 AL.46.18
# could not find admin2 CD.18.8335011
# could not find admin2 CD.23.9179898
# could not find admin2 CD.11.33
# could not find admin2 CD.22.922772
# missing admin codes 3513090 Willemstad CW
# could not find admin2 DE.13.00
# could not find admin2 DE.08.00
# could not find admin2 DE.06.00
# could not find admin2 DE.16.00
# could not find admin2 DE.06.00
# could not find admin2 DE.15.00
# could not find admin2 DE.16.00
# could not find admin2 DE.08.00
# could not find admin2 DE.16.00
# could not find admin2 DE.16.00
# could not find admin2 DE.12.00
# could not find admin2 DE.16.00
# could not find admin2 DE.06.00
# could not find admin2 DE.09.00
# could not find admin2 DE.12.00
# could not find admin2 DE.16.00
# could not find admin2 DE.04.00
# could not find admin2 DE.16.00
# could not find admin2 DE.11.00
# could not find admin2 DE.13.00
# could not find admin2 DE.16.00
# could not find admin2 DE.06.00
# could not find admin2 DE.06.00
# could not find admin2 DE.10.00
# could not find admin2 DE.08.00
# could not find admin2 DE.14.00
# could not find admin2 DE.10.00
# could not find admin2 DE.16.00
# could not find admin2 DE.12.00
# could not find admin2 DE.16.00
# could not find admin2 DE.16.00
# could not find admin2 DE.08.00
# could not find admin2 DE.14.00
# could not find admin2 DE.06.00
# could not find admin2 DE.08.00
# could not find admin2 DE.10.00
# could not find admin2 DE.16.00
# could not find admin2 DE.13.00
# could not find admin2 DE.16.00
# could not find admin2 DE.16.00
# could not find admin2 DE.08.00
# could not find admin2 DE.13.00
# could not find admin2 DE.10.00
# could not find admin2 DE.08.00
# could not find admin2 DE.15.00
# could not find admin2 DE.06.00
# could not find admin2 DE.16.00
# could not find admin2 DE.04.00
# could not find admin2 DE.06.00
# could not find admin2 DE.04.00
# could not find admin2 DE.04.00
# could not find admin2 DE.04.00
# could not find admin2 DE.04.00
# could not find admin2 DE.04.00
# could not find admin2 DE.04.00
# could not find admin2 DE.14.00
# could not find admin2 DE.13.00
# could not find admin2 DE.06.00
# could not find admin2 DE.16.00
# could not find admin2 DE.15.00
# could not find admin2 DE.06.00
# could not find admin2 DE.16.00
# could not find admin2 DE.10.00
# could not find admin2 DE.15.00
# could not find admin2 DE.13.00
# could not find admin2 DE.14.00
# could not find admin2 DE.06.00
# could not find admin2 DE.11.00
# could not find admin2 DE.13.00
# could not find admin2 DE.16.00
# could not find admin2 DE.06.00
# could not find admin2 DE.03.00
# could not find admin2 DE.03.00
# could not find admin2 DE.06.00
# could not find admin2 DE.04.00
# could not find admin2 DE.16.00
# could not find admin2 DE.16.00
# could not find admin2 DE.04.00
# could not find admin2 DE.04.00
# missing admin codes 2462881 Laayoune EH
# could not find admin1 EH.CE
# could not find admin2 HR.21.3186885
# could not find admin2 KR.13.Ansŏng-si
# could not find admin2 MG.51.8299677
# could not find admin2 MG.41.11072817
# could not find admin1 MO.02
# missing admin codes 2377450 Nouakchott MR
# could not find admin1 nan.21
# could not find admin2 PH.NCR.D9
# could not find admin2 PH.12.34
# could not find admin2 PH.14.B8
# could not find admin2 RU.73.Zelenodol'skiy Rayon
# could not find admin2 RU.17.Gorod Khasavyurt
# could not find admin2 RU.73.Chistopol'skiy Rayon
# could not find admin2 RU.73.Bugul'minskiy Rayon
# could not find admin2 RU.73.Al’met’yevskiy Rayon
# could not find admin1 SG.01
# could not find admin1 SG.00
# could not find admin1 SG.03
# could not find admin1 SG.00

# %% [markdown]
# parentId, childId, type. The type 'ADM' stands for the admin hierarchy modeled by the admin1-4 codes. The other entries are entered with the user interface. The relation toponym-adm hierarchy is not included in the file, it can instead be built from the admincodes of the toponym.

# %%
len(terms)
# Out:
# 48961

# %%
# 
HIERARCHY_URL = "https://download.geonames.org/export/dump/hierarchy.zip"
hierarchy_df = MODULE.ensure_zip_df(
    url=HIERARCHY_URL, inner_path="hierarchy.txt",
    read_csv_kwargs=dict(
        header=None,
        names=["parent", "child", "relation"],
    ),
)
hierarchy_df

# %%
hierarchy_df.relation.unique()
